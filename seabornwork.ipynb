# %% [markdown]
# seaborn work

# %%
from matplotlib import pyplot as plt

# %%
x = [10, 20, 30, 40]
y = [ 0, 15, 10, 25]

# %%
plt.plot(x, y)

# %%
import seaborn as sns

# %%
sns.set()

# %%
plt.plot(x,y)
