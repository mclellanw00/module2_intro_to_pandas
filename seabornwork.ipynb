# %% [markdown]
# seaborn work

# %%
from matplotlib import pyplot as plt

# %%
x = [10, 20, 30, 40]
y = [ 0, 15, 10, 25]

# %%
plt.plot(x, y)

# %%
import seaborn as sns

# %%
sns.set()

# %%
plt.plot(x,y)

# %%
sns.set_style("white")

# %%
plt.plot(x,y)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.5.1'

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
cars = sns.load_dataset('mpg')

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.dropna(inplace=True)
cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(x='model_year', y='mpg', col='origin', hue='cylinders', 
            data=cars);

# %%
sns.relplot(x='model_year', y='mpg', col='origin', hue='cylinders', data=cars);

# %% [markdown]
# WORK WITH SCATTERPLOTS!!

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.head
# Out:
# <bound method NDFrame.head of        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %%
diamonds = diamonds[
            diamonds.cut.isin(['Premium', 'Good', 'Very Good']) &
            diamonds.color.isin(['D','F','J'])
            ].sample(n=100, random_state=22)
diamonds.shape
# Out:
# (100, 10)

# %%
sns.set_style("darkgrid")

# %%
sns.scatterplot(diamonds.carat, diamonds.price)
# Out:
# /home/wil/.pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='x',y='y',data=diamonds)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# these x and y values are actual variables in the data set to make a good model

# %%
sns.scatterplot(x='carat', y='price', hue='cut', data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', hue='cut', data=diamonds,
                palette=['purple', 'red', '#55CCCC'])
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', hue='depth', data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# ^^ looking at the depth percentage, which is a continous variable mapping the lower and higher percentages of depth

# %% [markdown]
# changing the plot shapes

# %%
sns.scatterplot(x='carat', y='price', style='cut', data=diamonds,
                s = 100)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# changing the sizes based off the type of cut for the diamonds

# %%
sns.scatterplot(x='carat', y='price', size='cut',
                data=diamonds, 
                s=[300, 200, 100]
               )
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# sizes are more difficult to see to the human eye vs. the colors

# %% [markdown]
# putting it all together

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                style='cut',
                data=diamonds,
                s = 150
               )
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                style='cut',
                alpha = 0.75,
                edgecolor = 'black',
                data=diamonds,
                s = 150
               )
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>
